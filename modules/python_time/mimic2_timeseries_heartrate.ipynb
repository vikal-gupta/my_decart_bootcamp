# %% [markdown]
# # Identifying Patient Cohorts in [MIMIC-II](http://www.ncbi.nlm.nih.gov/pmc/articles/PMC3124312/)

# %%
# %matplotlib inline

# %%
import pymysql
import pandas as pd
import getpass
import pandas as pd
import seaborn as sns
import datetime
import time
import matplotlib.pyplot as plt

# %%
conn = pymysql.connect(host="mysql",
                       port=3306,user="jovyan",
                       passwd=getpass.getpass("Enter MySQL passwd for jovyan"),db='mimic2')
cursor = conn.cursor()
# Out:
# Enter MySQL passwd for jovyan········

# %% [markdown]
# ## Example Query: Heart Rate and Blood Pressure
#
# #### Select a patient from the following ids
# * 12613
# * 11923
# * 517
# * 14898

# %%
hr = pd.read_sql("""SELECT subject_id, 
                           icustay_id, 
                           charttime, 
                           realtime,
                           value1num,
                           value1uom
                    FROM chartevents
                    WHERE itemid in (211) AND
                          subject_id in (11923)"""
    ,conn)
hr.head()
# Out:
#    subject_id  icustay_id            charttime             realtime  \
# 0       11923       14882  2654-09-28 11:45:00  2654-09-28 11:57:00
# 1       11923       14882  2654-09-28 12:00:00  2654-09-28 12:04:00
# 2       11923       14882  2654-09-28 12:05:00  2654-09-28 13:36:00
# 3       11923       14882  2654-09-28 12:10:00  2654-09-28 13:36:00
# 4       11923       14882  2654-09-28 12:15:00  2654-09-28 13:36:00
#
#    value1num value1uom
# 0        115       BPM
# 1        118       BPM
# 2        122       BPM
# 3        177       BPM
# 4        194       BPM

# %%
bp = pd.read_sql("""SELECT subject_id, 
                           icustay_id, 
                           charttime, 
                           realtime,
                           value1num,
                           value1uom,
                           value2num,
                           value2uom
                    FROM chartevents
                    WHERE itemid in (6, 51, 455, 6701) AND
                          subject_id in (11923)"""
    ,conn)
bp.head()
# Out:
#    subject_id  icustay_id            charttime             realtime  \
# 0       11923       14882  2654-09-28 12:20:00  2654-09-28 13:36:00
# 1       11923       14882  2654-09-28 12:25:00  2654-09-28 13:36:00
# 2       11923       14882  2654-09-28 12:30:00  2654-09-28 13:36:00
# 3       11923       14882  2654-09-28 12:35:00  2654-09-28 13:36:00
# 4       11923       14882  2654-09-28 12:40:00  2654-09-28 13:36:00
#
#    value1num value1uom  value2num value2uom
# 0        117      mmHg         46      mmHg
# 1        185      mmHg         43      mmHg
# 2        248      mmHg         49      mmHg
# 3        192      mmHg         50      mmHg
# 4        159      mmHg         50      mmHg

# %%
bp["subject_id"].unique()
# Out:
# array([11923])

# %%
print(bp["icustay_id"].value_counts())
print(bp["subject_id"].value_counts())
# Out:
# 14882    4361
# 14884     199
# Name: icustay_id, dtype: int64
# 11923    4560
# Name: subject_id, dtype: int64

# %%
hr["icustay_id"].value_counts()
# Out:
# 14882    4106
# 14884     191
# Name: icustay_id, dtype: int64

# %% [markdown]
# ### Plot Heart Rate as a Time Series

# %%
hr.plot(x="realtime", y="value1num")
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# /opt/conda/lib/python3.5/site-packages/pandas/tseries/tools.py in _convert_listlike(arg, box, format, name)
#     379             try:
# --> 380                 values, tz = tslib.datetime_to_datetime64(arg)
#     381                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/tslib.pyx in pandas.tslib.datetime_to_datetime64 (pandas/tslib.c:27186)()
#
# pandas/tslib.pyx in pandas.tslib._check_dts_bounds (pandas/tslib.c:26695)()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 2654-09-28 11:57:00
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-20-5203bbb23f60> in <module>()
# ----> 1 hr.plot(x="realtime", y="value1num")
#
# /opt/conda/lib/python3.5/site-packages/pandas/tools/plotting.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3669                           fontsize=fontsize, colormap=colormap, table=table,
#    3670                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3671                           sort_columns=sort_columns, **kwds)
#    3672     __call__.__doc__ = plot_frame.__doc__
#    3673
#
# /opt/conda/lib/python3.5/site-packages/pandas/tools/plotting.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2554                  yerr=yerr, xerr=xerr,
#    2555                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2556                  **kwds)
#    2557
#    2558
#
# /opt/conda/lib/python3.5/site-packages/pandas/tools/plotting.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2362                 if com.is_integer(x) and not data.columns.holds_integer():
#    2363                     x = data.columns[x]
# -> 2364                 data = data.set_index(x)
#    2365
#    2366             if y is not None:
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    2784             arrays.append(level)
#    2785
# -> 2786         index = MultiIndex.from_arrays(arrays, names=names)
#    2787
#    2788         if verify_integrity and not index.is_unique:
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/index.py in from_arrays(cls, arrays, sortorder, names)
#    4742         if len(arrays) == 1:
#    4743             name = None if names is None else names[0]
# -> 4744             return Index(arrays[0], name=name)
#    4745
#    4746         cats = [Categorical.from_array(arr, ordered=True) for arr in arrays]
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/index.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     177                         tslib.is_timestamp_array(subarr)):
#     178                         from pandas.tseries.index import DatetimeIndex
# --> 179                         return DatetimeIndex(subarr, copy=copy, name=name, **kwargs)
#     180                     elif (inferred.startswith('timedelta') or
#     181                           lib.is_timedelta_array(subarr)):
#
# /opt/conda/lib/python3.5/site-packages/pandas/util/decorators.py in wrapper(*args, **kwargs)
#      87                 else:
#      88                     kwargs[new_arg_name] = new_arg_value
# ---> 89             return func(*args, **kwargs)
#      90         return wrapper
#      91     return _deprecate_kwarg
#
# /opt/conda/lib/python3.5/site-packages/pandas/tseries/index.py in __new__(cls, data, freq, start, end, periods, copy, name, tz, verify_integrity, normalize, closed, ambiguous, dtype, **kwargs)
#     317                 except ValueError:
#     318                     # tz aware
# --> 319                     subarr = tools._to_datetime(data, box=False, utc=True)
#     320
#     321                 # we may not have been able to convert
#
# /opt/conda/lib/python3.5/site-packages/pandas/tseries/tools.py in _to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, freq, infer_datetime_format)
#     393         return _convert_listlike(arg, box, format, name=arg.name)
#     394     elif com.is_list_like(arg):
# --> 395         return _convert_listlike(arg, box, format)
#     396
#     397     return _convert_listlike(np.array([ arg ]), box, format)[0]
#
# /opt/conda/lib/python3.5/site-packages/pandas/tseries/tools.py in _convert_listlike(arg, box, format, name)
#     381                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     382             except (ValueError, TypeError):
# --> 383                 raise e
#     384
#     385     if arg is None:
#
# /opt/conda/lib/python3.5/site-packages/pandas/tseries/tools.py in _convert_listlike(arg, box, format, name)
#     370                                                  yearfirst=yearfirst, freq=freq,
#     371                                                  unit=unit,
# --> 372                                                  require_iso8601=require_iso8601)
#     373
#     374             if com.is_datetime64_dtype(result) and box:
#
# pandas/tslib.pyx in pandas.tslib.array_to_datetime (pandas/tslib.c:37093)()
#
# pandas/tslib.pyx in pandas.tslib.array_to_datetime (pandas/tslib.c:35930)()
#
# pandas/tslib.pyx in pandas.tslib.array_to_datetime (pandas/tslib.c:34110)()
#
# pandas/tslib.pyx in pandas.tslib.array_to_datetime (pandas/tslib.c:34009)()
#
# pandas/tslib.pyx in pandas.tslib._check_dts_bounds (pandas/tslib.c:26695)()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 2654-09-28 11:57:00

# %% [markdown]
# #### What went wrong?
#
# As part of their de-identication process, the MIMIC2 creators have created large, random time shifts. We can look at the first data point to see what our calendar is

# %%
pip -install --upgrade pandas
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip -install --upgrade pandas
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more informations on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
import conda

# %%
pd.__version__
# Out:
# '0.17.1'

# %%
print(hr["realtime"][0])
# Out:
# 2654-09-28 11:57:00

# %% [markdown]
# #### Our data is from the year 2654 which for whatever reason pandas can't plot.
# ### We can shift the data back to our own time
# #### Compute the timedelta between the now and the first data point.

# %%
first_time = hr["realtime"][0]
time_delta = first_time - datetime.datetime.now()
print(time_delta.days)
# Out:
# 232741

# %%
first_time - time_delta
# Out:
# datetime.datetime(2017, 7, 7, 20, 0, 20, 607184)

# %% [markdown]
# ## Exercise: Use Pandas apply to create new columns with charttimes and real times shifted to starting at the current  date for the heart rate and blood pressure data

# %%
hr["new charttime"] = hr["charttime"] - time_delta
hr["new realtime"] = hr["realtime"] - time_delta

bp["new charttime"] = bp["charttime"] - time_delta
bp["new realtime"] = bp["realtime"] - time_delta
bp.head()
# Out:
#    subject_id  icustay_id            charttime             realtime  \
# 0       11923       14882  2654-09-28 12:20:00  2654-09-28 13:36:00
# 1       11923       14882  2654-09-28 12:25:00  2654-09-28 13:36:00
# 2       11923       14882  2654-09-28 12:30:00  2654-09-28 13:36:00
# 3       11923       14882  2654-09-28 12:35:00  2654-09-28 13:36:00
# 4       11923       14882  2654-09-28 12:40:00  2654-09-28 13:36:00
#
#    value1num value1uom  value2num value2uom              new charttime  \
# 0        117      mmHg         46      mmHg 2017-07-07 20:23:20.607184
# 1        185      mmHg         43      mmHg 2017-07-07 20:28:20.607184
# 2        248      mmHg         49      mmHg 2017-07-07 20:33:20.607184
# 3        192      mmHg         50      mmHg 2017-07-07 20:38:20.607184
# 4        159      mmHg         50      mmHg 2017-07-07 20:43:20.607184
#
#                 new realtime
# 0 2017-07-07 21:39:20.607184
# 1 2017-07-07 21:39:20.607184
# 2 2017-07-07 21:39:20.607184
# 3 2017-07-07 21:39:20.607184
# 4 2017-07-07 21:39:20.607184

# %%
hr[hr["icustay_id"]==14882].plot(x="new charttime", 
                                 y="value1num")
hr[hr["icustay_id"]!=14882].plot(x="new charttime", 
                                 y="value1num", color='red')

# %%
bp.rename(columns ={"value1num":"systolic", "value2num" :"diastolic"},
         inplace=True)

# %%
hr.rename(columns ={"value1num":"systolic", "value2num" :"diastolic"},
         inplace=True)

# %%
bp[bp["icustay_id"]==14882].plot(x="new charttime", 
                                 y=["systolic", "diastolic"])
bp[bp["icustay_id"]!=14882].plot(x="new charttime", 
                                 y=["systolic", "diastolic"])

# %%
hr[hr["icustay_id"]==14882].plot(x="new charttime", 
                                 y=["systolic", "diastolic"])
hr[hr["icustay_id"]!=14882].plot(x="new charttime", 
                                 y=["systolic", "diastolic"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-ae1c069e351c> in <module>()
#       1 hr[hr["icustay_id"]==14882].plot(x="new charttime",
# ----> 2                                  y=["systolic", "diastolic"])
#       3 hr[hr["icustay_id"]!=14882].plot(x="new charttime",
#       4                                  y=["systolic", "diastolic"])
#
# /opt/conda/lib/python3.5/site-packages/pandas/tools/plotting.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3669                           fontsize=fontsize, colormap=colormap, table=table,
#    3670                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3671                           sort_columns=sort_columns, **kwds)
#    3672     __call__.__doc__ = plot_frame.__doc__
#    3673
#
# /opt/conda/lib/python3.5/site-packages/pandas/tools/plotting.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2554                  yerr=yerr, xerr=xerr,
#    2555                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2556                  **kwds)
#    2557
#    2558
#
# /opt/conda/lib/python3.5/site-packages/pandas/tools/plotting.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2368                     y = data.columns[y]
#    2369                 label = kwds['label'] if 'label' in kwds else y
# -> 2370                 series = data[y].copy()  # Don't modify
#    2371                 series.name = label
#    2372
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1961         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1962             # either boolean or fancy integer index
# -> 1963             return self._getitem_array(key)
#    1964         elif isinstance(key, DataFrame):
#    1965             return self._getitem_frame(key)
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2005             return self.take(indexer, axis=0, convert=False)
#    2006         else:
# -> 2007             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2008             return self.take(indexer, axis=1, convert=True)
#    2009
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1148                 mask = check == -1
#    1149                 if mask.any():
# -> 1150                     raise KeyError('%s not in index' % objarr[mask])
#    1151
#    1152                 return _values_from_object(indexer)
#
# KeyError: "['diastolic'] not in index"

# %%
hr["chart delta"] = \   #line- continuation
hr.apply(lambda x: (x["charttime"] - 
                        x["realtime"]).total_seconds(), axis=1)
hr.head()
# Out:
#    subject_id  icustay_id            charttime             realtime  \
# 0       11923       14882  2654-09-28 11:45:00  2654-09-28 11:57:00
# 1       11923       14882  2654-09-28 12:00:00  2654-09-28 12:04:00
# 2       11923       14882  2654-09-28 12:05:00  2654-09-28 13:36:00
# 3       11923       14882  2654-09-28 12:10:00  2654-09-28 13:36:00
# 4       11923       14882  2654-09-28 12:15:00  2654-09-28 13:36:00
#
#    value1num value1uom              new charttime               new realtime  \
# 0        115       BPM 2017-07-07 19:48:20.607184 2017-07-07 20:00:20.607184
# 1        118       BPM 2017-07-07 20:03:20.607184 2017-07-07 20:07:20.607184
# 2        122       BPM 2017-07-07 20:08:20.607184 2017-07-07 21:39:20.607184
# 3        177       BPM 2017-07-07 20:13:20.607184 2017-07-07 21:39:20.607184
# 4        194       BPM 2017-07-07 20:18:20.607184 2017-07-07 21:39:20.607184
#
#    chart delta
# 0         -720
# 1         -240
# 2        -5460
# 3        -5160
# 4        -4860

# %% [markdown]
# ## Exercise: Timestamp from datetime
# #### Using ``time.mktime`` and ``datetime.timetuple`` create timestamps for each measurement

# %%
time.mktime(first_time.timetuple())

# %%
hr[["new charttime","new realtime","chart delta"]][hr["icustay_id"]==14882].plot.line(x="new charttime", 
                               y="chart delta")
